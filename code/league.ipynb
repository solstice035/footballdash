# %%
import pandas as pd

# %%
df_origin = pd.read_csv('../data/E0.csv')

df_origin.head(10)
# Out:
#   Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2  E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3  E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
# 5  E0  14/08/2021  15:00   Leicester          Wolves     1     0   H     1
# 6  E0  14/08/2021  15:00     Watford     Aston Villa     3     2   H     2
# 7  E0  14/08/2021  17:30     Norwich       Liverpool     0     3   A     0
# 8  E0  15/08/2021  14:00   Newcastle        West Ham     2     4   A     2
# 9  E0  15/08/2021  16:30   Tottenham        Man City     1     0   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...

# %%
print(list(df_origin.columns.tolist()))
# Out:
# ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'PSCH', 'PSCD', 'PSCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA']

# %%
keepcols = ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR']

df = df_origin[keepcols]

df.head()
# Out:
#   Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2  E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3  E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... HST AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     0  ...   3   4  12   8   2   5   0   0   0   0
# 1     0  ...   8   3  11   9   5   4   1   2   0   0
# 2     0  ...   3   8  10   7   7   6   2   1   0   0
# 3     0  ...   6   1  15  11   5   2   0   0   0   0
# 4     1  ...   6   3  13  15   6   8   2   0   0   0
#
# [5 rows x 24 columns]

# %%
def homepoints(FTR):
    if FTR == 'H':
        return 3
    if FTR == 'D':
        return 1
    if FTR == 'A':
        return 0
    return 0

def awaypoints(FTR):
    if FTR == 'A':
        return 3
    if FTR == 'D':
        return 1
    if FTR == 'H':
        return 0
    return 0


df2 = df.copy()
df2.loc[:, 'HomePoints'] = df.loc[:, 'FTR'].apply(homepoints)
df2.loc[:, ('AwayPoints')] = df.loc[:, ('FTR')].apply(awaypoints)
df2.loc[:, 'Score'] = df['FTHG'].astype(str) + '-' + df['FTAG'].astype(str)

df2.head()
# Out:
#   Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2  E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3  E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ...  AF HC  AC  HY  AY  HR  AR  HomePoints  AwayPoints  Score
# 0     0  ...   8  2   5   0   0   0   0           3           0    2-0
# 1     0  ...   9  5   4   1   2   0   0           3           0    5-1
# 2     0  ...   7  7   6   2   1   0   0           0           3    1-2
# 3     0  ...  11  5   2   0   0   0   0           3           0    3-0
# 4     1  ...  15  6   8   2   0   0   0           3           0    3-1
#
# [5 rows x 27 columns]

# %%
df2['Date'] = pd.to_datetime(df2['Date']).dt.date
print(df2['Date'].dtype)
df2.head(10)
# Out:
# object
# c:\Users\2006431\OneDrive - EY\70-Dev\01-Projects\nufcDashboard\.venv\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\Users\2006431\OneDrive - EY\70-Dev\01-Projects\nufcDashboard\.venv\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\Users\2006431\OneDrive - EY\70-Dev\01-Projects\nufcDashboard\.venv\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/08/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
# df2.pivot_table(index=['HomeTeam'], columns='AwayTeam', values='Score', fill_value='-', aggfunc='first')

# %%
def homeleague(x):
        results = {
            'HomePoints': x['HomePoints'].sum(),
            'HomeWins': x[x['FTR']== 'H']['HomeTeam'].count(),
            'HomeDraws': x[x['FTR']== 'D']['HomeTeam'].count(),
            'HomeLoss': x[x['FTR']== 'A']['HomeTeam'].count(),
            'HomeGoalsFor': x['FTHG'].sum(),
            'HomeGoalsAgainst': x['FTAG'].sum(),
            'HomeGoalsDiff': x['FTHG'].sum() - x['FTAG'].sum()
        }
        return pd.Series(results)

def awayleague(x):
    results = {
        'AwayPoints': x['AwayPoints'].sum(),
        'AwayWins': x[x['FTR']== 'A']['AwayTeam'].count(),
        'AwayDraws': x[x['FTR']== 'D']['AwayTeam'].count(),
        'AwayLoss': x[x['FTR']== 'H']['AwayTeam'].count(),
        'AwayGoalsFor': x['FTAG'].sum(),
        'AwayGoalsAgainst': x['FTHG'].sum(),
        'AwayGoalsDiff': x['FTAG'].sum() - x['FTHG'].sum()
    }
    return pd.Series(results)

df_homeleague = df2.groupby('HomeTeam').apply(homeleague)
df_awayleague = df2.groupby('AwayTeam').apply(awayleague)
df_league_temp = pd.merge(df_homeleague, df_awayleague, left_index=True, right_index=True)

df_league_temp.head(20)
# Out:
#                 HomePoints  HomeWins  HomeDraws  HomeLoss  HomeGoalsFor  \
# HomeTeam
# Arsenal                 41        13          2         4            35
# Aston Villa             23         6          5         8            29
# Brentford               24         7          3         9            22
# Brighton                22         5          7         7            19
# Burnley                 21         5          6         8            18
# Chelsea                 34         9          7         3            37
# Crystal Palace          29         7          8         4            27
# Everton                 29         9          2         8            27
# Leeds                   18         4          6         9            19
# Leicester               34        10          4         5            34
# Liverpool               49        15          4         0            49
# Man City                47        15          2         2            58
# ...

# %%
def league(x):
    results = {
        'Points': x['HomePoints'].sum() + x['AwayPoints'].sum(),
        'Wins': x['HomeWins'].sum() + x['AwayWins'].sum(),
        'Draws':  x['HomeDraws'].sum() + x['AwayDraws'].sum(),
        'Loss': x['HomeLoss'].sum() + x['AwayLoss'].sum(),
        'GoalsFor': x['HomeGoalsFor'].sum() + x['AwayGoalsFor'].sum(),
        'GoalsAgainst': x['HomeGoalsAgainst'].sum() + x['AwayGoalsAgainst'].sum(),
        'GoalDifference': x['HomeGoalsDiff'].sum() + x['AwayGoalsDiff'].sum()
    }
    return pd.Series(results)

df_league = df_league_temp.groupby('HomeTeam').apply(league)

df_league.sort_values(by='Points', ascending=False, inplace=True)

df_league.head(20)
# Out:
#                 Points  Wins  Draws  Loss  GoalsFor  GoalsAgainst  \
# HomeTeam
# Man City            93    29      6     3        99            26
# Liverpool           92    28      8     2        94            26
# Chelsea             74    21     11     6        76            33
# Tottenham           71    22      5    11        69            40
# Arsenal             69    22      3    13        61            48
# Man United          58    16     10    12        57            57
# West Ham            56    16      8    14        60            51
# Leicester           52    14     10    14        62            59
# Brighton            51    12     15    11        42            44
# Wolves              51    15      6    17        38            43
# Newcastle           49    13     10    15        44            62
# Crystal Palace      48    11     15    12        50            46
# Brentford           46    13      7    18        48            56
# ...

# %%
# Best away results

df_away_results = df_league_temp.loc[:, ('AwayPoints', 'AwayGoalsDiff')]

awaypoints = df_away_results.loc[:, ('AwayPoints')].mean()
#  average away points
print('Average away points: ', awaypoints)

# Average away goal difference
awaygoaldiff = df_away_results.loc[:, ('AwayGoalsDiff')].mean()
print('Average away goal difference: ', awaygoaldiff)

# filter away teams with more than 2 points
df_away_results = df_away_results[(df_away_results['AwayPoints'] > awaypoints) & (df_away_results['AwayGoalsDiff'] > awaygoaldiff)]

df_away_results.sort_values(by='AwayPoints', ascending=False, inplace=True)
df_away_results.head(10)
# Out:
# Average away points:  23.75
# Average away goal difference:  -3.95
#            AwayPoints  AwayGoalsDiff
# HomeTeam
# Man City           46             30
# Liverpool          43             28
# Chelsea            40             28
# Tottenham          31             10
# Brighton           29              2
# Wolves             27              0
# West Ham           24              2

# %%
# get last 5 results for home teams
team = 'Newcastle'

df_newcastle = df2.query("(HomeTeam == @team) or (AwayTeam == @team)")

df_newcastle.head(38)
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 8    E0  2021-08-15  14:00       Newcastle        West Ham     2     4   A
# 11   E0  2021-08-21  15:00     Aston Villa       Newcastle     2     0   H
# 23   E0  2021-08-28  15:00       Newcastle     Southampton     2     2   D
# 34   E0  2021-11-09  15:00      Man United       Newcastle     4     1   H
# 40   E0  2021-09-17  20:00       Newcastle           Leeds     1     1   D
# 55   E0  2021-09-25  15:00         Watford       Newcastle     1     1   D
# 64   E0  2021-02-10  15:00          Wolves       Newcastle     2     1   H
# 78   E0  2021-10-17  16:30       Newcastle       Tottenham     2     3   A
# 82   E0  2021-10-23  15:00  Crystal Palace       Newcastle     1     1   D
# 94   E0  2021-10-30  15:00       Newcastle         Chelsea     0     3   A
# 105  E0  2021-06-11  17:30        Brighton       Newcastle     1     1   D
# ...

# %%
def form(x):
    if x['HomeTeam'] == 'Newcastle' and x['FTR'] == 'H':
        return 'W'
    if x['AwayTeam'] == 'Newcastle' and x['FTR'] == 'A':
        return 'W'
    if x['HomeTeam'] == 'Newcastle' and x['FTR'] == 'A':
        return 'L'
    if x['AwayTeam'] == 'Newcastle' and x['FTR'] == 'H':
        return 'L'
    if x['FTR'] == 'D':
        return 'D'
    return 'U'

df_newcastle_form = df_newcastle.loc[:, ('HomeTeam', 'AwayTeam', 'FTR')]
df_newcastle_form.loc[:, 'Form'] = df_newcastle_form.apply(form, axis=1)
df_newcastle_form.reset_index(inplace=True)

df_newcastle_form = df_newcastle_form['Form']
df_newcastle_form.tail(5)
# Out:
# 33    W
# 34    L
# 35    L
# 36    W
# 37    W
# Name: Form, dtype: object
