# %% [markdown]
# # Statsbomb Free Data tier
# Playing with statsbomb data on the free tier
# Premier league data is 2004 only (sad face emoji)

# %%
import pandas as pd
from statsbombpy import sb

# %%
# show all competitions
sb.competitions()
# Out:
# c:\Users\2006431\OneDrive - EY\70-Dev\01-Projects\nufcDashboard\.venv\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# ...

# %%
# filter country_name to England
# sb.competitions(country_name='England')

# show unique competitions
sb.competitions().drop_duplicates(['country_name', 'competition_name'])
# Out:
# c:\Users\2006431\OneDrive - EY\70-Dev\01-Projects\nufcDashboard\.venv\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 15              37         90                   England
# 18              43        106             International
# 20            1238        108                     India
# 21              11         90                     Spain
# 38              49          3  United States of America
# 39               2         44                   England
# 40              55         43                    Europe
# 41              53        106                    Europe
# 42              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 0          Champions League               male              False
# ...

# %%
df = sb.matches(competition_id=11, season_id=90)
# sort df most recent first
df = df.sort_values('match_date', ascending=False)
df.head(20)
# Out:
#     match_id  match_date      kick_off      competition     season  \
# 0    3773457  2021-05-16  18:30:00.000  Spain - La Liga  2020/2021
# 17   3773387  2021-05-11  22:00:00.000  Spain - La Liga  2020/2021
# 16   3773372  2021-05-08  16:15:00.000  Spain - La Liga  2020/2021
# 18   3773695  2021-05-02  21:00:00.000  Spain - La Liga  2020/2021
# 15   3773586  2021-04-29  19:00:00.000  Spain - La Liga  2020/2021
# 33   3773689  2021-04-25  16:15:00.000  Spain - La Liga  2020/2021
# 20   3773661  2021-04-22  22:00:00.000  Spain - La Liga  2020/2021
# 3    3773497  2021-04-10  21:00:00.000  Spain - La Liga  2020/2021
# 27   3773474  2021-04-05  21:00:00.000  Spain - La Liga  2020/2021
# 21   3773597  2021-03-21  21:00:00.000  Spain - La Liga  2020/2021
# 19   3773369  2021-03-15  21:00:00.000  Spain - La Liga  2020/2021
# 2    3773665  2021-03-06  21:00:00.000  Spain - La Liga  2020/2021
# 28   3773625  2021-02-27  16:15:00.000  Spain - La Liga  2020/2021
# ...
