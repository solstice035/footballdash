# %%
# Connect to SQL database with SqlAlchemy  
import pyodbc
import sqlalchemy as sql
from sqlalchemy import create_engine

server = 'UK5057993W1\SQLEXPRESS'
database = 'AdventureWorks'
driver = 'ODBC Driver 17 for SQL Server'

# create connection string
conn_str = f"mssql+pyodbc://{server}?DATABASE={database}?driver={driver}?trusted_connection=yes"
# create engine
engine = sql.create_engine(conn_str)

# create connection
conn = engine.connect()

# %%
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=UK5057993W1\SQLEXPRESS;DATABASE=AdventureWorks;Trusted_Connection=yes;')
cursor = conn.cursor()
cursor.execute('SELECT TOP(10)* FROM Sales.Store')

# print the first 10 rows
for row in cursor:
    print(row)

# %%
import pyodbc
from sqlalchemy import create_engine
engine = create_engine(
    "mssql+pyodbc://UK5057993W1\SQLEXPRESS/AdventureWorks?driver=ODBC+Driver+17+for+SQL+Server?trusted_connection=yes",
)
# conn = engine.connect()
engine.execute("SELECT TOP(10)* FROM Sales.Store").fetchall()
# print the first 10 rows
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File c:\Users\2006431\OneDrive - EY\70-Dev\01-Projects\nufcDashboard\.venv\lib\site-packages\sqlalchemy\engine\base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File c:\Users\2006431\OneDrive - EY\70-Dev\01-Projects\nufcDashboard\.venv\lib\site-packages\sqlalchemy\pool\base.py:325, in Pool.connect(self)
#     318 """Return a DBAPI connection from the pool.
#     319
#     320 The connection is instrumented such that when its
#    (...)
#     323
#     324 """
# --> 325 return _ConnectionFairy._checkout(self)
#
# File c:\Users\2006431\OneDrive - EY\70-Dev\01-Projects\nufcDashboard\.venv\lib\site-packages\sqlalchemy\pool\base.py:888, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     887 if not fairy:
# ...
