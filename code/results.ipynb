# %% [markdown]
# ## Environment Set Up

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
keepcols = [
    "Div",
    "Date",
    "Time",
    "HomeTeam",
    "AwayTeam",
    "FTHG",
    "FTAG",
    "FTR",
    "HTHG",
    "HTAG",
    "HTR",
    "Referee",
    "HS",
    "AS",
    "HST",
    "AST",
    "HF",
    "AF",
    "HC",
    "AC",
    "HY",
    "AY",
    "HR",
    "AR",
]

results = pd.read_csv(
    "../data/E0.csv", usecols=keepcols, parse_dates=["Date"], dayfirst=True
)

results.head()
# Out:
#   Div       Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0 2021-08-13  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0 2021-08-14  12:30  Man United           Leeds     5     1   H     1
# 2  E0 2021-08-14  15:00     Burnley        Brighton     1     2   A     1
# 3  E0 2021-08-14  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0 2021-08-14  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... HST AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     0  ...   3   4  12   8   2   5   0   0   0   0
# 1     0  ...   8   3  11   9   5   4   1   2   0   0
# 2     0  ...   3   8  10   7   7   6   2   1   0   0
# 3     0  ...   6   1  15  11   5   2   0   0   0   0
# 4     1  ...   6   3  13  15   6   8   2   0   0   0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Data Transformation
#
# ### Melt
#
# creates new dataframe (team_results) with 2 rows per match

# %%
## converting each matchup into 2 rows
## one where each team is 'current_team' and opponent is identfied
results["H"] = results["HomeTeam"]
results["A"] = results["AwayTeam"]
cols_to_keep = [
    "Div",
    "Date",
    "HomeTeam",
    "AwayTeam",
    "FTHG",
    "FTAG",
    "FTR",
    "HTHG",
    "HTAG",
    "HTR",
    "Referee",
]

team_results = pd.melt(
    results,
    id_vars=cols_to_keep,
    value_vars=["H", "A"],
    var_name="Home/Away",
    value_name="Team",
)

team_results["Opponent"] = np.where(
    team_results["Team"] == team_results["HomeTeam"],
    team_results["AwayTeam"],
    team_results["HomeTeam"],
)


team_results.head(20)
# Out:
#    Div       Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0   E0 2021-08-13       Brentford         Arsenal     2     0   H     1     0
# 1   E0 2021-08-14      Man United           Leeds     5     1   H     1     0
# 2   E0 2021-08-14         Burnley        Brighton     1     2   A     1     0
# 3   E0 2021-08-14         Chelsea  Crystal Palace     3     0   H     2     0
# 4   E0 2021-08-14         Everton     Southampton     3     1   H     0     1
# 5   E0 2021-08-14       Leicester          Wolves     1     0   H     1     0
# 6   E0 2021-08-14         Watford     Aston Villa     3     2   H     2     0
# 7   E0 2021-08-14         Norwich       Liverpool     0     3   A     0     1
# 8   E0 2021-08-15       Newcastle        West Ham     2     4   A     2     1
# 9   E0 2021-08-15       Tottenham        Man City     1     0   H     0     0
# 10  E0 2021-08-21       Liverpool         Burnley     2     0   H     1     0
# 11  E0 2021-08-21     Aston Villa       Newcastle     2     0   H     1     0
# 12  E0 2021-08-21  Crystal Palace       Brentford     0     0   D     0     0
# 13  E0 2021-08-21           Leeds         Everton     2     2   D     1     1
# 14  E0 2021-08-21        Man City         Norwich     5     0   H     2     0
# 15  E0 2021-08-21        Brighton         Watford     2     0   H     2     0
# 16  E0 2021-08-22     Southampton      Man United     1     1   D     1     0
# 17  E0 2021-08-22          Wolves       Tottenham     0     1   A     0     1
# 18  E0 2021-08-22         Arsenal         Chelsea     0     2   A     0     2
# 19  E0 2021-08-23        West Ham       Leicester     4     1   H     1     0
#
#    HTR     Referee Home/Away            Team        Opponent
# 0    H    M Oliver         H       Brentford         Arsenal
# 1    H   P Tierney         H      Man United           Leeds
# 2    H     D Coote         H         Burnley        Brighton
# 3    H      J Moss         H         Chelsea  Crystal Palace
# 4    A    A Madley         H         Everton     Southampton
# 5    H    C Pawson         H       Leicester          Wolves
# 6    H      M Dean         H         Watford     Aston Villa
# 7    A  A Marriner         H         Norwich       Liverpool
# 8    H  M Atkinson         H       Newcastle        West Ham
# 9    D    A Taylor         H       Tottenham        Man City
# 10   H      M Dean         H       Liverpool         Burnley
# 11   H     D Coote         H     Aston Villa       Newcastle
# 12   D  M Atkinson         H  Crystal Palace       Brentford
# 13   D   D England         H           Leeds         Everton
# 14   H     G Scott         H        Man City         Norwich
# 15   H    A Taylor         H        Brighton         Watford
# 16   H    C Pawson         H     Southampton      Man United
# 17   A   S Attwell         H          Wolves       Tottenham
# 18   A   P Tierney         H         Arsenal         Chelsea
# 19   H    M Oliver         H        West Ham       Leicester

# %%
team_results.tail(20)
# Out:
#     Div       Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 740  E0 2022-05-15           Leeds        Brighton     1     1   D     0
# 741  E0 2022-05-15         Watford       Leicester     1     5   A     1
# 742  E0 2022-05-15        West Ham        Man City     2     2   D     2
# 743  E0 2022-05-15          Wolves         Norwich     1     1   D     0
# 744  E0 2022-05-15         Everton       Brentford     2     3   A     2
# 745  E0 2022-05-16       Newcastle         Arsenal     2     0   H     0
# 746  E0 2022-05-17     Southampton       Liverpool     1     2   A     1
# 747  E0 2022-05-19         Everton  Crystal Palace     3     2   H     0
# 748  E0 2022-05-19     Aston Villa         Burnley     1     1   D     0
# 749  E0 2022-05-19         Chelsea       Leicester     1     1   D     1
# 750  E0 2022-05-22         Arsenal         Everton     5     1   H     2
# 751  E0 2022-05-22       Brentford           Leeds     1     2   A     0
# 752  E0 2022-05-22        Brighton        West Ham     3     1   H     0
# 753  E0 2022-05-22         Burnley       Newcastle     1     2   A     0
# 754  E0 2022-05-22         Chelsea         Watford     2     1   H     1
# 755  E0 2022-05-22  Crystal Palace      Man United     1     0   H     1
# 756  E0 2022-05-22       Leicester     Southampton     4     1   H     0
# 757  E0 2022-05-22       Liverpool          Wolves     3     1   H     1
# 758  E0 2022-05-22        Man City     Aston Villa     3     2   H     0
# 759  E0 2022-05-22         Norwich       Tottenham     0     5   A     0
#
#      HTAG HTR       Referee Home/Away            Team        Opponent
# 740     1   A        M Dean         A        Brighton           Leeds
# 741     2   A     J Gillett         A       Leicester         Watford
# 742     0   H      A Taylor         A        Man City        West Ham
# 743     1   A  T Harrington         A         Norwich          Wolves
# 744     1   H      M Oliver         A       Brentford         Everton
# 745     0   D     D England         A         Arsenal       Newcastle
# 746     1   D    M Atkinson         A       Liverpool     Southampton
# 747     2   A      A Taylor         A  Crystal Palace         Everton
# 748     1   A     P Tierney         A         Burnley     Aston Villa
# 749     1   D     S Attwell         A       Leicester         Chelsea
# 750     1   H    A Marriner         A         Everton         Arsenal
# 751     0   D     P Tierney         A           Leeds       Brentford
# 752     1   A      K Friend         A        West Ham        Brighton
# 753     1   A      C Pawson         A       Newcastle         Burnley
# 754     0   H        M Dean         A         Watford         Chelsea
# 755     0   H    M Atkinson         A      Man United  Crystal Palace
# 756     0   D        J Moss         A     Southampton       Leicester
# 757     1   D      A Taylor         A          Wolves       Liverpool
# 758     1   A      M Oliver         A     Aston Villa        Man City
# 759     2   A    C Kavanagh         A       Tottenham         Norwich

# %% [markdown]
# ## Get Points from Results

# %%
# Function and Dictionary

points_map = {
    'W': 3,
    'D': 1,
    'L': 0
}

def get_result(score, score_opp):
    if score == score_opp:
        return 'D'
    elif score > score_opp:
        return 'W'
    else:
        return 'L'

# %%
# full time goals
team_results["Goals"] = np.where(
    team_results["Team"] == team_results["HomeTeam"],
    team_results["FTHG"],
    team_results["FTAG"],
)
team_results["Goals_Opp"] = np.where(
    team_results["Team"] != team_results["HomeTeam"],
    team_results["FTHG"],
    team_results["FTAG"],
)
team_results["Result"] = np.vectorize(get_result)(
    team_results["Goals"], team_results["Goals_Opp"]
)
team_results["Points"] = team_results["Result"].map(points_map)

team_results["Score"] = team_results["Goals"].astype(str) + '-' + team_results["Goals_Opp"].astype(str) 

'''
# 1st half goals
team_results["1H_Goals"] = np.where(
    team_results["Team"] == team_results["HomeTeam"],
    team_results["HTHG"],
    team_results["HTAG"],
)
team_results["1H_Goals_Opp"] = np.where(
    team_results["Team"] != team_results["HomeTeam"],
    team_results["HTHG"],
    team_results["HTAG"],
)
team_results["1H_Result"] = np.vectorize(get_result)(
    team_results["1H_Goals"], team_results["1H_Goals_Opp"]
)
team_results["1H_Points"] = team_results["1H_Result"].map(points_map)

# 2nd half goals
team_results["2H_Goals"] = team_results["Goals"] - team_results["1H_Goals"]
team_results["2H_Goals_Opp"] = team_results["Goals_Opp"] - team_results["1H_Goals_Opp"]
team_results["2H_Result"] = np.vectorize(get_result)(
    team_results["2H_Goals"], team_results["2H_Goals_Opp"]
)
team_results["2H_Points"] = team_results["2H_Result"].map(points_map)
'''
# Out:
# '\n# 1st half goals\nteam_results["1H_Goals"] = np.where(\n    team_results["Team"] == team_results["HomeTeam"],\n    team_results["HTHG"],\n    team_results["HTAG"],\n)\nteam_results["1H_Goals_Opp"] = np.where(\n    team_results["Team"] != team_results["HomeTeam"],\n    team_results["HTHG"],\n    team_results["HTAG"],\n)\nteam_results["1H_Result"] = np.vectorize(get_result)(\n    team_results["1H_Goals"], team_results["1H_Goals_Opp"]\n)\nteam_results["1H_Points"] = team_results["1H_Result"].map(points_map)\n\n# 2nd half goals\nteam_results["2H_Goals"] = team_results["Goals"] - team_results["1H_Goals"]\nteam_results["2H_Goals_Opp"] = team_results["Goals_Opp"] - team_results["1H_Goals_Opp"]\nteam_results["2H_Result"] = np.vectorize(get_result)(\n    team_results["2H_Goals"], team_results["2H_Goals_Opp"]\n)\nteam_results["2H_Points"] = team_results["2H_Result"].map(points_map)\n'

# %%
# Drop unnecessary columns and sort by date
cols_to_drop = ['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR']
team_results = (team_results
                    .drop(cols_to_drop, axis=1)
                    .sort_values(by=['Date', 'Referee']))

# %%
team_results.head(20)
# Out:
#     Div       Date     Referee Home/Away            Team        Opponent  \
# 0    E0 2021-08-13    M Oliver         H       Brentford         Arsenal
# 380  E0 2021-08-13    M Oliver         A         Arsenal       Brentford
# 4    E0 2021-08-14    A Madley         H         Everton     Southampton
# 384  E0 2021-08-14    A Madley         A     Southampton         Everton
# 7    E0 2021-08-14  A Marriner         H         Norwich       Liverpool
# 387  E0 2021-08-14  A Marriner         A       Liverpool         Norwich
# 5    E0 2021-08-14    C Pawson         H       Leicester          Wolves
# 385  E0 2021-08-14    C Pawson         A          Wolves       Leicester
# 2    E0 2021-08-14     D Coote         H         Burnley        Brighton
# 382  E0 2021-08-14     D Coote         A        Brighton         Burnley
# 3    E0 2021-08-14      J Moss         H         Chelsea  Crystal Palace
# 383  E0 2021-08-14      J Moss         A  Crystal Palace         Chelsea
# 6    E0 2021-08-14      M Dean         H         Watford     Aston Villa
# 386  E0 2021-08-14      M Dean         A     Aston Villa         Watford
# 1    E0 2021-08-14   P Tierney         H      Man United           Leeds
# 381  E0 2021-08-14   P Tierney         A           Leeds      Man United
# 9    E0 2021-08-15    A Taylor         H       Tottenham        Man City
# 389  E0 2021-08-15    A Taylor         A        Man City       Tottenham
# 8    E0 2021-08-15  M Atkinson         H       Newcastle        West Ham
# 388  E0 2021-08-15  M Atkinson         A        West Ham       Newcastle
#
#      Goals  Goals_Opp Result  Points Score
# 0        2          0      W       3   2-0
# 380      0          2      L       0   0-2
# 4        3          1      W       3   3-1
# 384      1          3      L       0   1-3
# 7        0          3      L       0   0-3
# 387      3          0      W       3   3-0
# 5        1          0      W       3   1-0
# 385      0          1      L       0   0-1
# 2        1          2      L       0   1-2
# 382      2          1      W       3   2-1
# 3        3          0      W       3   3-0
# 383      0          3      L       0   0-3
# 6        3          2      W       3   3-2
# 386      2          3      L       0   2-3
# 1        5          1      W       3   5-1
# 381      1          5      L       0   1-5
# 9        1          0      W       3   1-0
# 389      0          1      L       0   0-1
# 8        2          4      L       0   2-4
# 388      4          2      W       3   4-2

# %%
team_results.to_pickle('../data/pickle/team_results.pkl')
